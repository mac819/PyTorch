# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Data Generation

# %%
# Variable Initialized
true_b = 1
true_w = 2
N = 100

# Data Generation by y = mx + c + epsilon
np.random.seed(42)
x = np.random.rand(N, 1) # Create an array of the given shape (N, 1) and populate it with random samples from a uniform distribution
epsilon = (0.1 * np.random.randn(N, 1)) # Return a sample (or samples) from the "standard normal" distribution.
y = true_b + true_w*x + epsilon

# %%
print(x.shape, y.shape)
# Out:
# (100, 1) (100, 1)

# %% [markdown]
# ## Train Test Split of Dataset

# %%
# Shuffles the indices
idx = np.arange(N)
np.random.shuffle(idx)

# Uses first 80 random indices for train
train_idx = idx[:int(N*.8)]
# Uses the remaining indices for validation
val_idx = idx[int(N*.8):]

# Generates train and validation sets
x_train, y_train = x[train_idx], y[train_idx]
x_val, y_val = x[val_idx], y[val_idx]

# Displaying the training set which we will be using in this chapter (first 5 values)
print('x_train: {}'.format(x_train[:5]))
# Out:
# x_train: [[0.77127035]
#  [0.06355835]
#  [0.86310343]
#  [0.02541913]
#  [0.73199394]]

# %%
figure, axis = plt.subplots(1, 2, figsize=(10, 3))

axis[0].scatter(x_train, y_train)
axis[0].set_title("Train data points")

axis[1].scatter(x_val, y_val)
axis[1].set_title("Test data points")
plt.show()

# %% [markdown]
# ## Using Gradient Descent

# %%
# Step 0 - initializes parameters "b" and "w" randomly
np.random.seed(42)
b = np.random.randn(1)
w = np.random.randn(1)

# Step 1 - computes our model's predicted output - forward pass
yhat = b + w * x_train 
# Displaying the model's predicted output using current parameter values (first five values)
print(yhat[:5])
# Out:
# [[0.390075  ]
#  [0.4879263 ]
#  [0.37737776]
#  [0.4931996 ]
#  [0.39550552]]

# %%
plt.figure(figsize=(5, 3))
plt.scatter(x_train, y_train)
plt.plot(x_train, yhat, linestyle='dotted', marker='o')
plt.show()
